# %%
# !pip3 install opencv-python
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread("./f1.jpg")

# %%
plt.imshow(img)

# %%
face_detector=cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

# %%
faces=face_detector.detectMultiScale(img,1.3,5)

# %%
faces.shape
# Out:
# (4, 4)

# %%
faces
# Out:
# array([[462,  70, 110, 110],
#        [596,  88,  87,  87],
#        [175,  74, 144, 144],
#        [328, 100, 107, 107]], dtype=int32)

# %%
faces[0]
# Out:
# array([462,  70, 110, 110], dtype=int32)

# %%
x,y,w,h=faces[0]

# %%
x
# Out:
# 462

# %%
y
# Out:
# 70

# %%
w
# Out:
# 110

# %%
h
# Out:
# 110

# %%
new_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)

# %%
plt.imshow(new_img)

# %%
for face in faces:
    x,y,w,h=face
    new_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)

# %%
plt.imshow(new_img)

# %%
img2=plt.imread("./f11.jpg")

# %%
plt.imshow(img2)

# %%
f_d=cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

# %%
f=f_d.detectMultiScale(img2,1.3,5)

# %%
f
# Out:
# array([[196,  45,  37,  37],
#        [256,  50,  38,  38],
#        [120,  66,  40,  40],
#        [552,  80,  45,  45],
#        [388,  51,  38,  38],
#        [314,  54,  37,  37],
#        [290, 111,  40,  40],
#        [172,  87,  44,  44],
#        [ 96, 106,  35,  35],
#        [229, 112,  38,  38],
#        [346,  95,  42,  42],
#        [ 49, 167,  41,  41],
#        [451, 150,  40,  40],
#        [149, 163,  44,  44],
#        [248, 166,  43,  43],
#        [334, 152,  48,  48],
#        [553, 153,  49,  49]], dtype=int32)

# %%
f.shape
# Out:
# (17, 4)

# %%
for i in f:
    x,y,w,h=i
    n_img=cv2.rectangle(img2,(x,y),(x+w,y+h),(255,255,255),2)

# %%
plt.imshow(n_img)

# %%
cam = cv2.VideoCapture(0)

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
while True:
    ret, frame = cam.read()
    if ret == False:
        continue
        
    face_detector=cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")   
    faces = face_detector.detectMultiScale(frame, 1.2, 5)
    for face in faces:
        x,y,w,h = face
        frame = cv2.rectangle(frame , (x,y) , (x+w, y+h), (255,255,255), 2 )
        
    cv2.imshow("Face Detection", frame)
    
    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed == ord('q'):
        break

cam.release()
cv2.destroyAllWindows()

# %%
ord('q')
# Out:
# 113
